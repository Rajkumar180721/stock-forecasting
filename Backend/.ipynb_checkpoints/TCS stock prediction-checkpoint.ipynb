# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense,LSTM,Dropout
# Out:
# 2022-11-06 15:15:39.436432: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
data = pd.read_csv('datasets/INFY.csv')
data = data.dropna()
train, test = train_test_split(data, test_size=0.1, shuffle=False)
train.shape, test.shape
# Out:
# ((1525, 7), (170, 7))

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1695 entries, 0 to 1694
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1695 non-null   object
#  1   Open       1695 non-null   float64
#  2   High       1695 non-null   float64
#  3   Low        1695 non-null   float64
#  4   Close      1695 non-null   float64
#  5   Adj Close  1695 non-null   float64
#  6   Volume     1695 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 92.8+ KB

# %%
trainData = train.iloc[:,4:5].values
sc = MinMaxScaler(feature_range=(0,1))
trainData = sc.fit_transform(trainData)
trainData.shape
# Out:
# (1525, 1)

# %%
X_train = []
y_train = []

for i in range (60,1149): #60 : timestep // 1149 : length of the data
    X_train.append(trainData[i-60:i,0]) 
    y_train.append(trainData[i,0])

X_train,y_train = np.array(X_train),np.array(y_train)

# %%
X_train = np.reshape(X_train,(X_train.shape[0],X_train.shape[1],1)) #adding the batch_size axis
X_train.shape
# Out:
# (1089, 60, 1)

# %%
model = Sequential()

model.add(LSTM(units=100, return_sequences = True, input_shape =(X_train.shape[1],1)))
model.add(Dropout(0.2))

model.add(LSTM(units=100, return_sequences = True))
model.add(Dropout(0.2))

model.add(LSTM(units=100, return_sequences = True))
model.add(Dropout(0.2))

model.add(LSTM(units=100, return_sequences = False))
model.add(Dropout(0.2))

model.add(Dense(units =1))
model.compile(optimizer='adam',loss="mean_squared_error")

# %%
hist = model.fit(X_train, y_train, epochs = 20, batch_size = 32, verbose=2)
# Out:
# Epoch 1/20
# 35/35 - 10s - loss: 0.0029 - 10s/epoch - 272ms/step
# Epoch 2/20
# 35/35 - 4s - loss: 8.9403e-04 - 4s/epoch - 122ms/step
# Epoch 3/20
# 35/35 - 4s - loss: 7.9294e-04 - 4s/epoch - 121ms/step
# Epoch 4/20
# 35/35 - 4s - loss: 7.1713e-04 - 4s/epoch - 120ms/step
# Epoch 5/20
# 35/35 - 4s - loss: 5.5401e-04 - 4s/epoch - 124ms/step
# Epoch 6/20
# 35/35 - 4s - loss: 5.1383e-04 - 4s/epoch - 124ms/step
# Epoch 7/20
# 35/35 - 5s - loss: 4.5180e-04 - 5s/epoch - 129ms/step
# Epoch 8/20
# 35/35 - 4s - loss: 4.6107e-04 - 4s/epoch - 127ms/step
# Epoch 9/20
# 35/35 - 4s - loss: 4.4954e-04 - 4s/epoch - 127ms/step
# Epoch 10/20
# 35/35 - 4s - loss: 4.5662e-04 - 4s/epoch - 124ms/step
# Epoch 11/20
# 35/35 - 4s - loss: 8.6465e-04 - 4s/epoch - 122ms/step
# Epoch 12/20
# 35/35 - 4s - loss: 3.9357e-04 - 4s/epoch - 128ms/step
# Epoch 13/20
# 35/35 - 4s - loss: 3.4495e-04 - 4s/epoch - 123ms/step
# Epoch 14/20
# 35/35 - 4s - loss: 3.5075e-04 - 4s/epoch - 124ms/step
# Epoch 15/20
# 35/35 - 4s - loss: 3.5556e-04 - 4s/epoch - 126ms/step
# Epoch 16/20
# 35/35 - 4s - loss: 3.0794e-04 - 4s/epoch - 123ms/step
# Epoch 17/20
# 35/35 - 4s - loss: 3.6518e-04 - 4s/epoch - 124ms/step
# Epoch 18/20
# 35/35 - 4s - loss: 3.4738e-04 - 4s/epoch - 121ms/step
# Epoch 19/20
# 35/35 - 4s - loss: 3.3320e-04 - 4s/epoch - 125ms/step
# Epoch 20/20
# 35/35 - 5s - loss: 8.2990e-04 - 5s/epoch - 130ms/step

# %%
plt.plot(hist.history['loss'])
plt.title('Training model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper right')
plt.show()

# %%
testData = test
testData = testData.iloc[:,4:5]
y_test = testData.iloc[60:,0:].values 
#input array for the model
inputClosing = testData.iloc[:,0:].values 
inputClosing_scaled = sc.transform(inputClosing)
inputClosing_scaled.shape
X_test = []
length = len(testData)
timestep = 60
for i in range(timestep,length):  
    X_test.append(inputClosing_scaled[i-timestep:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test,(X_test.shape[0],X_test.shape[1],1))
X_test.shape
# Out:
# (110, 60, 1)

# %%
y_pred = model.predict(X_test)
y_pred.shape
# Out:
# 4/4 [==============================] - 1s 38ms/step
# (110, 1)

# %%
predicted_price = sc.inverse_transform(y_pred)
predicted_price
# Out:
# array([[17.817596],
#        [17.297165],
#        [17.017445],
#        [17.010977],
#        [17.185143],
#        [17.455183],
#        [17.717648],
#        [17.913885],
#        [18.06791 ],
#        [18.129536],
#        [18.118261],
#        [18.074577],
#        [18.067448],
#        [18.082619],
#        [18.046577],
#        [17.936264],
#        [17.77207 ],
#        [17.562101],
#        [17.356043],
#        [17.191868],
#        [17.040398],
#        [16.967817],
#        [16.916975],
#        [16.84212 ],
#        [16.752735],
#        [16.69575 ],
#        [16.646345],
#        [16.568274],
#        [16.496214],
#        [16.515505],
#        [16.62808 ],
#        [16.808168],
#        [17.055042],
#        [17.313875],
#        [17.529589],
#        [17.660156],
#        [17.672077],
#        [17.550013],
#        [17.278496],
#        [16.869633],
#        [16.449394],
#        [16.131626],
#        [15.907723],
#        [15.773592],
#        [15.823625],
#        [16.015825],
#        [16.27979 ],
#        [16.565529],
#        [16.831842],
#        [17.010849],
#        [17.09046 ],
#        [17.076578],
#        [17.030073],
#        [16.97165 ],
#        [16.936625],
#        [16.957651],
#        [17.017424],
#        [17.024181],
#        [16.920933],
#        [16.719318],
#        [16.458744],
#        [16.228956],
#        [16.115175],
#        [16.161652],
#        [16.339155],
#        [16.627636],
#        [16.929935],
#        [17.131907],
#        [17.125486],
#        [17.004562],
#        [16.912708],
#        [16.945288],
#        [17.108494],
#        [17.32683 ],
#        [17.583616],
#        [17.84305 ],
#        [18.073185],
#        [18.235317],
#        [18.298662],
#        [18.286362],
#        [18.20435 ],
#        [18.071318],
#        [17.919817],
#        [17.786928],
#        [17.689713],
#        [17.621733],
#        [17.559647],
#        [17.473724],
#        [17.343266],
#        [17.191233],
#        [17.050364],
#        [16.896385],
#        [16.713484],
#        [16.532621],
#        [16.381956],
#        [16.297478],
#        [16.258183],
#        [16.23605 ],
#        [16.266062],
#        [16.366024],
#        [16.56822 ],
#        [16.858759],
#        [17.104048],
#        [17.17334 ],
#        [17.02345 ],
#        [16.678532],
#        [16.245066],
#        [15.803199],
#        [15.43045 ],
#        [15.147441]], dtype=float32)

# %%
plt.plot(y_test, color = 'red', label = 'Actual Stock Price')
plt.plot(predicted_price, color = 'green', label = 'Predicted Stock Price')
plt.title('Infosys stock price prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
